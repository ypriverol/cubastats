# %%
import plotly_express as px
import pandas as pd

# %% [markdown]
# # Evolution of scientific publications overtime for countries with more than 100 citables papers in 1996 and less than 20k citables papers in 2018. The size of the buble is the number of citations per document.

# %%
data_publications = pd.read_csv('../publications-low.csv')
px.scatter(data_publications, x="Citable documents", y="Citations", animation_frame="Year", animation_group="Country",
           size="Citations per document", color="Country", hover_name="Country", 
           log_x = True, 
           size_max=45, range_x=[50,20000], range_y=[1,60000])
# Out:
# <div>
#
#
#             <div id="4c831e9b-daea-4d40-b74f-80527daa6020" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c831e9b-daea-4d40-b74f-80527daa6020")) {
#                     Plotly.newPlot(
#                         '4c831e9b-daea-4d40-b74f-80527daa6020',
# ...

# %% [markdown]
# # Evolution of scientific publications overtime for countries with more than 10k citables papers in 1996. The size of the buble is the number of citations per document.

# %%
data_publications = pd.read_csv('../publications-high.csv')
px.scatter(data_publications, x="Citable documents", y="Citations", animation_frame="Year", animation_group="Country",
           size="Citations per document", color="Country", hover_name="Country", 
           log_x = True, 
           size_max=45, range_x=[2000,1000000], range_y=[20000,14000000])
# Out:
# <div>
#
#
#             <div id="84515cd6-521a-4667-95e0-7369218c3f87" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("84515cd6-521a-4667-95e0-7369218c3f87")) {
#                     Plotly.newPlot(
#                         '84515cd6-521a-4667-95e0-7369218c3f87',
# ...
